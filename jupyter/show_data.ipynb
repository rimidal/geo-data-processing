# %%
import pandas as pd

from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file,save
from bokeh.sampledata.periodic_table import elements

import numpy as np # we will use this later, so import it now

from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('../data/converted_poly15.csv',header=None)

# %%
points = pd.read_csv('../data/converted_points500.csv',header=None)

# %%
points = [eval(x) for x in points[1].tolist()]

# %%
coords =eval( data[1][2])   
lng = [x[1] for x in coords]
lat = [x[0] for x in coords]
lat = lat+lat[:-1]
lng = lng+lng[:-1]

lng_p = [x[1] for x in points]
lat_p = [x[0] for x in points]


v1 = np.random.rand(5)
v2 = np.random.rand(5)
# create a new plot with figure
p = figure(x_axis_type="datetime",plot_width=700, plot_height=500)

p.line(lat, lng,  line_color="red",  line_width=2)
p.circle(lat, lng,fill_color="white", size=8)
p.circle(lat_p, lng_p,fill_color="red", size=2)

show(p) # show the results
# Out:
#   <div class="bk-root" id="074bae04-22a8-4d83-a360-7cc9e9f093ea" data-root-id="3614"></div>
